# %% [markdown]
# <a href="https://colab.research.google.com/github/Nov05/Google-Colaboratory/blob/master/2019_06_29_plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# created by Wenjing Liu on 2019-06-29

# %%
import numpy as np
import pandas as pd

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
# plot = online mode, iplot = offline mode
from plotly.offline import init_notebook_mode, plot, iplot
from plotly.graph_objs import Histogram2dContour, Scatter
from plotly.graph_objs.histogram2dcontour import Contours
from plotly.graph_objs.scatter import Marker

# %%
import plotly
plotly.__version__
# Out:
# '3.6.1'

# %% [markdown]
# # Plotly Offline Mode in Jupyter  Notebook

# %%
# define this function for plotly and plotly express displaying
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
//// both would work, enjoy plotly and plotly express in colab
//               plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))
# init_notebook_mode(connected=False)

# %%
# then call it in EVERY cell (each is an iframe)
configure_plotly_browser_state()

x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', 
               marker=Marker(color='white', size=3, opacity=0.3))], 
       show_link=False)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
# //// both would work, enjoy plotly and plotly express in colab
# //               plotly: 'https://cdn.plot.ly/plotly-1.5.1.min.js?noext',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# ...

# %% [markdown]
# # Plotly Online Mode
#
# Note: There is a limit to daily access. For now (2019-07-05) the upper limit is 100.
# https://plot.ly/python/getting-started/

# %%
# if credentials file is set, then no need to call configure_plotly_browser_state().
# but there is a limit (so far it is 100) to online mode.

init_notebook_mode(connected=True)
plotly.tools.set_credentials_file(username='November05', api_key='*')
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
trace0 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = [trace0, trace1]

# an online plot will be generated
# e.g. 'https://plot.ly/~November05/2'
py.plot(data, filename = 'basic-line', auto_open=True)
# Out:
# 'https://plot.ly/~November05/2'

# %% [markdown]
# # Generating Offline Graphs within Jupyter Notebook

# %%
import plotly
import plotly.graph_objs as go

plotly.offline.plot({
    "data": [go.Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": go.Layout(title="hello world")
}, auto_open=True)

# file 'temp-plot.html' will be generated
# go to colab files, download the file, you can open the file in your browser
# Out:
# 'file:///content/temp-plot.html'
