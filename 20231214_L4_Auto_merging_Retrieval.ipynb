# %% [markdown]
# <a href="https://colab.research.google.com/github/Nov05/Google-Colaboratory/blob/master/20231214_L4_Auto_merging_Retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **\<top\>**
#
# * modified by nov05 on 2023-12-14
# * go to [the course](https://learn.deeplearning.ai/building-evaluating-advanced-rag/lesson/5/auto-merging-retrieval)
# * watch [the video](https://dft3h5i221ap1.cloudfront.net/LlamaIndex-TrueEra/C1/video/LITE_L3.mp4)
#
# ---
#
# * [check openai billing](https://platform.openai.com/account/billing/overview) (need to turn off the vpn web protection)

# %%
## download eBook-How-to-Build-a-Career-in-AI.pdf
# !gdown --no-check-certificate 'https://drive.google.com/uc?export=download&id=1uqjVyFAVVNMHjIduGyFERnnCMzgYgpwm'
## download generated_questions.text
# !gdown --no-check-certificate 'https://drive.google.com/uc?export=download&id=1nWvZAJWwSImfG8nRlGETz0JKGRkjAKdg'
## download utils.py
# !gdown --no-check-certificate 'https://drive.google.com/uc?export=download&id=1qHEVMw6wZV7NdOV3E68nZySkmvBhPZ5-'

# %%
# %%capture
# !pip install openai==1.3.5
# !pip install llama-index==0.9.8
# !pip install trulens-eval==0.18.1
# !pip install python-dotenv
# !pip install pypdf
# !pip uninstall transformers ## 4.35.2 pre-installed by colab
# !pip install transformers==4.33.2
# !pip install sentence-transformers==2.2.2
## restart the session

# %%
from google.colab import output
output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"]

# %% [markdown]
# # Lesson 4: Auto-merging Retrieval

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import utils
import os
import openai
openai.api_key = utils.get_openai_api_key()

# %%
from llama_index import SimpleDirectoryReader
documents = SimpleDirectoryReader(
    input_files=["./eBook-How-to-Build-a-Career-in-AI.pdf"]
).load_data()

# %%
print(type(documents))
print(len(documents))
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
# 41
# <class 'llama_index.schema.Document'>
# Doc ID: 26029a29-6444-4776-a63b-06e510b728b2
# Text: PAGE 1Founder, DeepLearning.AICollected Insights from Andrew Ng
# How to  Build Your Career in AIA Simple Guide

# %% [markdown]
# ## Auto-merging retrieval setup

# %%
from llama_index import Document
document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from llama_index.node_parser import HierarchicalNodeParser
# create the hierarchical node parser w/ default settings
node_parser = HierarchicalNodeParser.from_defaults(
    chunk_sizes=[2048, 512, 128]
)
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nodes = node_parser.get_nodes_from_documents([document])

# %%
from llama_index.node_parser import get_leaf_nodes
leaf_nodes = get_leaf_nodes(nodes)
print(leaf_nodes[30].text)
# Out:
# But this became less important as numerical linear algebra libraries matured.
# Deep learning is still an emerging technology, so when you train a neural network and the
# optimization algorithm struggles to converge, understanding the math behind gradient
# descent, momentum, and the Adam  optimization algorithm will help you make better decisions.
# Similarly, if your neural network does something funny — say, it makes bad predictions on
# images of a certain resolution, but not others — understanding the math behind neural network
# architectures puts you in a better position to figure out what to do.
# Of course, I also encourage learning driven by curiosity.

# %%
nodes_by_id = {node.node_id: node for node in nodes}
parent_node = nodes_by_id[leaf_nodes[30].parent_node.node_id]
print(parent_node.text)
# Out:
# PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? It’s always nice to know more math! But there’s so much to
# learn that, realistically, it’s necessary to prioritize. Here’s how you might go about strengthening
# your math background.
# To figure out what’s important to know, I find it useful to ask what you need to know to make
# the decisions required for the work you want to do. At DeepLearning.AI, we frequently ask,
# “What does someone need to know to accomplish their goals?” The goal might be building a
# machine learning model, architecting a system, or passing a job interview.
# Understanding the math behind algorithms you use is often helpful, since it enables you to
# debug them. But the depth of knowledge that’s useful changes over time. As machine learning
# techniques mature and become more reliable and turnkey, they require less debugging, and a
# shallower understanding of the math involved may be sufficient to make them work.
# For instance, in an earlier era of machine learning, linear algebra libraries for solving linear
# systems of equations (for linear regression) were immature. I had to understand how these
# libraries worked so I could choose among different libraries and avoid numerical roundoff
# pitfalls. But this became less important as numerical linear algebra libraries matured.
# Deep learning is still an emerging technology, so when you train a neural network and the
# optimization algorithm struggles to converge, understanding the math behind gradient
# descent, momentum, and the Adam  optimization algorithm will help you make better decisions.
# Similarly, if your neural network does something funny — say, it makes bad predictions on
# images of a certain resolution, but not others — understanding the math behind neural network
# architectures puts you in a better position to figure out what to do.
# Of course, I also encourage learning driven by curiosity. If something interests you, go ahead
# and learn it regardless of how useful it might turn out to be!  Maybe this will lead to a creative
# spark or technical breakthrough.How much math do you need to know to be a machine learning engineer?

# %% [markdown]
# ### Building the index

# %%
from llama_index.llms import OpenAI
llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
from llama_index import ServiceContext
auto_merging_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    node_parser=node_parser,
)
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
from llama_index import VectorStoreIndex, StorageContext
storage_context = StorageContext.from_defaults()
storage_context.docstore.add_documents(nodes)
automerging_index = VectorStoreIndex(
    leaf_nodes, storage_context=storage_context, service_context=auto_merging_context
)
automerging_index.storage_context.persist(persist_dir="./merging_index")

# %%
# This block of code is optional to check
# if an index file exist, then it will load it
# if not, it will rebuild it

import os
from llama_index import VectorStoreIndex, StorageContext, load_index_from_storage
from llama_index import load_index_from_storage

if not os.path.exists("./merging_index"):
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    automerging_index = VectorStoreIndex(
            leaf_nodes,
            storage_context=storage_context,
            service_context=auto_merging_context
        )

    automerging_index.storage_context.persist(persist_dir="./merging_index")
else:
    automerging_index = load_index_from_storage(
        StorageContext.from_defaults(persist_dir="./merging_index"),
        service_context=auto_merging_context
    )

# %% [markdown]
# ### Defining the retriever and running the query engine

# %%
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.retrievers import AutoMergingRetriever
from llama_index.query_engine import RetrieverQueryEngine

automerging_retriever = automerging_index.as_retriever(
    similarity_top_k=12
)

retriever = AutoMergingRetriever(
    automerging_retriever,
    automerging_index.storage_context,
    verbose=True
)

rerank = SentenceTransformerRerank(top_n=6, model="BAAI/bge-reranker-base")

auto_merging_engine = RetrieverQueryEngine.from_args(
    automerging_retriever, node_postprocessors=[rerank]
)
# Out:
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]

# %%
auto_merging_response = auto_merging_engine.query(
    "What is the importance of networking in AI?"
)

# %%
from llama_index.response.notebook_utils import display_response
display_response(auto_merging_response)
# Out:
# **`Final Response:`** Networking is important in AI because it allows individuals to build a strong professional network and community. This network can provide valuable information, help with career advancement, and offer support and advice when needed. By connecting with others in the AI community, individuals can also increase their visibility and recognition for their expertise. Additionally, networking can lead to referrals for potential job opportunities. Building a community and network in AI is seen as a more effective approach than traditional networking, as it focuses on fostering genuine relationships and connections.

# %% [markdown]
# ## Putting it all Together

# %%
import os

from llama_index import (
    ServiceContext,
    StorageContext,
    VectorStoreIndex,
    load_index_from_storage,
)
from llama_index.node_parser import HierarchicalNodeParser
from llama_index.node_parser import get_leaf_nodes
from llama_index import StorageContext, load_index_from_storage
from llama_index.retrievers import AutoMergingRetriever
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.query_engine import RetrieverQueryEngine


def build_automerging_index(
    documents,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index",
    chunk_sizes=None,
):
    chunk_sizes = chunk_sizes or [2048, 512, 128]
    node_parser = HierarchicalNodeParser.from_defaults(chunk_sizes=chunk_sizes)
    nodes = node_parser.get_nodes_from_documents(documents)
    leaf_nodes = get_leaf_nodes(nodes)
    merging_context = ServiceContext.from_defaults(
        llm=llm,
        embed_model=embed_model,
    )
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    if not os.path.exists(save_dir):
        automerging_index = VectorStoreIndex(
            leaf_nodes, storage_context=storage_context, service_context=merging_context
        )
        automerging_index.storage_context.persist(persist_dir=save_dir)
    else:
        automerging_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=save_dir),
            service_context=merging_context,
        )
    return automerging_index


def get_automerging_query_engine(
    automerging_index,
    similarity_top_k=12,
    rerank_top_n=6,
):
    base_retriever = automerging_index.as_retriever(similarity_top_k=similarity_top_k)
    retriever = AutoMergingRetriever(
        base_retriever, automerging_index.storage_context, verbose=True
    )
    rerank = SentenceTransformerRerank(
        top_n=rerank_top_n, model="BAAI/bge-reranker-base"
    )
    auto_merging_engine = RetrieverQueryEngine.from_args(
        retriever, node_postprocessors=[rerank]
    )
    return auto_merging_engine

# %%
from llama_index.llms import OpenAI
index = build_automerging_index(
    [document],
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    save_dir="./merging_index",
)

# %%
query_engine = get_automerging_query_engine(index, similarity_top_k=6)

# %% [markdown]
# ## TruLens Evaluation

# %%
from trulens_eval import Tru
Tru().reset_database()
# Out:
# 🦑 Tru initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `Tru` to prevent this.

# %% [markdown]
# ### Two layers

# %%
auto_merging_index_0 = build_automerging_index(
    documents,
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index_0",
    chunk_sizes=[2048,512],
)

# %%
auto_merging_engine_0 = get_automerging_query_engine(
    auto_merging_index_0,
    similarity_top_k=12,
    rerank_top_n=6,
)

# %%
from utils import get_prebuilt_trulens_recorder
tru_recorder = get_prebuilt_trulens_recorder(
    auto_merging_engine_0,
    app_id ='app_0'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
eval_questions = []
with open('generated_questions.text', 'r') as file:
    for line in file:
        # Remove newline character and convert to integer
        item = line.strip()
        eval_questions.append(item)

# %%
def run_evals(eval_questions, tru_recorder, query_engine):
    for question in eval_questions:
        with tru_recorder as recording:
            response = query_engine.query(question)

# %%
run_evals(eval_questions, tru_recorder, auto_merging_engine_0)
# Out:
# > Merging 1 nodes into parent node.
# > Parent node id: 1e4e2e8f-d016-45ae-b41e-efe208dcbacc.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1891da98-1b69-4c41-8110-92e803d13394.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 41eef54c-3292-49ca-9d66-2f4631d379f3.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6bd892f4-deea-48b9-b3ad-7e8ce0492f1c.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5591a4c5-7291-4a2c-8721-61725c482a2b.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6bd892f4-deea-48b9-b3ad-7e8ce0492f1c.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 41eef54c-3292-49ca-9d66-2f4631d379f3.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 951c752b-69dc-4ca6-94fc-ef7e5b8df8b4.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 03d68251-a6e9-4ad9-8a79-a992c1924293.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ef29ee83-10ed-47d6-9bc4-9bc6e2ada415.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 274668c5-3e52-47f4-b1c2-db558045b996.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: ef29ee83-10ed-47d6-9bc4-9bc6e2ada415.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c36ba6d1-a488-4bd9-9439-b0a8d2e87ed8.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3acb113c-ed5e-4c2f-83cf-626b49b74df8.
# > Parent node text: PAGE 11
# The Best Way to Build
# a New Habit
# One of my favorite books is BJ Fogg’s, Tiny Habits: Th...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1e4e2e8f-d016-45ae-b41e-efe208dcbacc.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1891da98-1b69-4c41-8110-92e803d13394.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: fa7795dc-9a3f-4809-abda-4aff052d2f70.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: fa7795dc-9a3f-4809-abda-4aff052d2f70.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1891da98-1b69-4c41-8110-92e803d13394.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5591a4c5-7291-4a2c-8721-61725c482a2b.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: fa7795dc-9a3f-4809-abda-4aff052d2f70.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5591a4c5-7291-4a2c-8721-61725c482a2b.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: e8305bfb-1b73-4077-9f5b-7e31b29bb6a3.
# > Parent node text: PAGE 31Finding the Right
# AI Job for YouCHAPTER 9
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3d15ff5b-abc8-463b-977e-1565c8d28712.
# > Parent node text: PAGE 34Keys to Building a
# Career in AICHAPTER 10
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c36ba6d1-a488-4bd9-9439-b0a8d2e87ed8.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 41eef54c-3292-49ca-9d66-2f4631d379f3.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e50036ed-a00e-49e9-a7f1-65e00eb8697b.
# > Parent node text: PAGE 5Three Steps to
# Career GrowthCHAPTER 1
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dee65c34-52c1-4d51-be2f-15091d280002.
# > Parent node text: PAGE 21Building a Portfolio of
# Projects that Shows
# Skill Progression CHAPTER 6
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1891da98-1b69-4c41-8110-92e803d13394.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1e4e2e8f-d016-45ae-b41e-efe208dcbacc.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 41eef54c-3292-49ca-9d66-2f4631d379f3.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 817a3539-c784-4fff-88ac-fab08cdcee9a.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ba12d1c8-fcc8-4da9-9faf-b39533ecfabe.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0578ed3f-278e-4c34-9ac8-0f0cf488fc66.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c36ba6d1-a488-4bd9-9439-b0a8d2e87ed8.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: a3f11518-387e-4cef-9237-a1c461c856a2.
# > Parent node text: PAGE 40Make Every Day CountFinal Thoughts
# Every year on my birthday, I get to thinking about the ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3acb113c-ed5e-4c2f-83cf-626b49b74df8.
# > Parent node text: PAGE 11
# The Best Way to Build
# a New Habit
# One of my favorite books is BJ Fogg’s, Tiny Habits: Th...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 41eef54c-3292-49ca-9d66-2f4631d379f3.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6bd892f4-deea-48b9-b3ad-7e8ce0492f1c.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8aa04c55-71f8-4108-be74-12626e257e77.
# > Parent node text: PAGE 2"AI is the new
# electricity. It will
# transform and improve
# all areas of human life."
# Andr...
#
# > Merging 1 nodes into parent node.
# > Parent node id: fa7795dc-9a3f-4809-abda-4aff052d2f70.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: e50036ed-a00e-49e9-a7f1-65e00eb8697b.
# > Parent node text: PAGE 5Three Steps to
# Career GrowthCHAPTER 1
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 03d68251-a6e9-4ad9-8a79-a992c1924293.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ef29ee83-10ed-47d6-9bc4-9bc6e2ada415.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 38a5f515-b056-4fc4-bd24-4d585f88593a.
# > Parent node text: PAGE 14Scoping Successful
# AI ProjectsCHAPTER 4
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 951c752b-69dc-4ca6-94fc-ef7e5b8df8b4.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: e50036ed-a00e-49e9-a7f1-65e00eb8697b.
# > Parent node text: PAGE 5Three Steps to
# Career GrowthCHAPTER 1
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dee65c34-52c1-4d51-be2f-15091d280002.
# > Parent node text: PAGE 21Building a Portfolio of
# Projects that Shows
# Skill Progression CHAPTER 6
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 951c752b-69dc-4ca6-94fc-ef7e5b8df8b4.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6efbb12-eb7c-4bfc-89c7-42915bf4251b.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 951c752b-69dc-4ca6-94fc-ef7e5b8df8b4.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 274668c5-3e52-47f4-b1c2-db558045b996.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 817a3539-c784-4fff-88ac-fab08cdcee9a.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8aa04c55-71f8-4108-be74-12626e257e77.
# > Parent node text: PAGE 2"AI is the new
# electricity. It will
# transform and improve
# all areas of human life."
# Andr...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ef29ee83-10ed-47d6-9bc4-9bc6e2ada415.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c36ba6d1-a488-4bd9-9439-b0a8d2e87ed8.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 274668c5-3e52-47f4-b1c2-db558045b996.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: e50036ed-a00e-49e9-a7f1-65e00eb8697b.
# > Parent node text: PAGE 5Three Steps to
# Career GrowthCHAPTER 1
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 817a3539-c784-4fff-88ac-fab08cdcee9a.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 817a3539-c784-4fff-88ac-fab08cdcee9a.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 274668c5-3e52-47f4-b1c2-db558045b996.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 03d68251-a6e9-4ad9-8a79-a992c1924293.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ef29ee83-10ed-47d6-9bc4-9bc6e2ada415.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 343b5dbe-8587-47a9-a239-7910d24531f4.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 203fddea-2245-4bef-8d0c-f76a15049686.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: dce63e4c-815a-4e0e-96e0-2748c6b4e747.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 412c745d-ca79-47f7-837a-7d5a75ed2cea.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a1e3cd1-11d2-48df-beec-42e66aa56efc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 38a5f515-b056-4fc4-bd24-4d585f88593a.
# > Parent node text: PAGE 14Scoping Successful
# AI ProjectsCHAPTER 4
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 274668c5-3e52-47f4-b1c2-db558045b996.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 53f6691c-7c6d-4dd3-94c7-e68b72bdb116.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ba12d1c8-fcc8-4da9-9faf-b39533ecfabe.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 80107109-be02-43d0-a498-a8162a1800ca.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 817a3539-c784-4fff-88ac-fab08cdcee9a.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 542f1084-7a64-43b1-bcee-694463ae3534.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 66f1ce44-bc80-42f4-9f9c-17d85cc742ec.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 793f8b39-b807-420e-8a32-91ad79c62249.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: da96050d-5ffd-400f-9a4d-51e25cfe3ff7.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f77e0870-8b0b-47d6-8029-d5ae1ea0c8a9.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 72f4713a-c00f-4756-bf57-2f4416db98c2.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 125b7559-ff48-4bfd-8f20-89dfbc825e1b.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: eb35914d-ffc3-4cc9-a1a6-b5ea3ceb621d.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...

# %%
from trulens_eval import Tru
Tru().get_leaderboard(app_ids=[])
# Out:
#         Groundedness  Context Relevance  Answer Relevance    latency  \
# app_id
# app_0       0.843333           0.254545          0.991304  47.291667
#
#         total_cost
# app_id
# app_0     0.003781

# %%
Tru().run_dashboard()
# Out:
# Starting dashboard ...
# npx: installed 22 in 4.717s
#
# Go to this url and submit the ip given here. your url is: https://gold-comics-peel.loca.lt
#
#   Submit this IP Address: 35.231.56.55
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ### Three layers

# %%
auto_merging_index_1 = build_automerging_index(
    documents,
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index_1",
    chunk_sizes=[2048,512,128],
)

# %%
auto_merging_engine_1 = get_automerging_query_engine(
    auto_merging_index_1,
    similarity_top_k=12,
    rerank_top_n=6,
)

# %%
tru_recorder = get_prebuilt_trulens_recorder(
    auto_merging_engine_1,
    app_id ='app_1'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
run_evals(eval_questions, tru_recorder, auto_merging_engine_1)
# Out:
# > Merging 4 nodes into parent node.
# > Parent node id: c71d347e-39ac-4a71-ab6c-183cc55baa0d.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 7db48f01-933e-4637-963a-f29452bed96c.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ccb3138c-6c4f-438e-b71c-5ad70c2ddc7e.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 45efbeb9-47df-4f51-980c-85098f2bc5b2.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 5 nodes into parent node.
# > Parent node id: b74d5cea-897d-430c-92ba-748dcba3e699.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3d4356f9-6ee3-4155-8fc0-a14817cd0191.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 58c67af7-402b-4d55-ac00-0d2e5e64e771.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 028eefbd-c887-4636-bea9-8971951196a4.
# > Parent node text: But when committing to a direction means making a costly investment or entering a one-
# way door  ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 0ced9c7f-b45f-46f0-bea8-7396bd97cfdd.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 13ecd5a4-c19d-49e8-bdf3-739711fcd910.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9801bec4-fc2e-4dc5-8e2e-0b0850a95db7.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7fe4e2ca-a36c-411e-9177-cdb17f069893.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f6433f00-dac6-40f3-9cbf-001c4c159d4f.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 4 nodes into parent node.
# > Parent node id: 37cb673a-fedc-4d2d-9378-b0d412beca35.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 4 nodes into parent node.
# > Parent node id: ff9a8693-d146-414e-bdc3-b34dc1e739e5.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c19781c6-5179-466b-b858-85a4e6c25274.
# > Parent node text: I’ve found EDA particularly
# useful in data-centric AI development, where analyzing errors and ga...
#
# > Merging 2 nodes into parent node.
# > Parent node id: b24fde1c-d625-45c2-a394-ac6df4110bba.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 97c7749c-59c7-47c0-a2c7-ac7ec8943317.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0e622b32-1733-4ae1-b87d-3ab85382a10b.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: dd6ad95a-2c1b-401d-86eb-713d754f9493.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 4 nodes into parent node.
# > Parent node id: e5b01757-2eb1-4c9d-bfc4-4e7520971e58.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ddbf6e5f-3bbb-4503-949c-170eab1cf4e3.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 13ecd5a4-c19d-49e8-bdf3-739711fcd910.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7fe4e2ca-a36c-411e-9177-cdb17f069893.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 5 nodes into parent node.
# > Parent node id: e5b01757-2eb1-4c9d-bfc4-4e7520971e58.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ddbf6e5f-3bbb-4503-949c-170eab1cf4e3.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7dd0bc21-d666-4043-b4b9-409605b60063.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 4f58ee5c-6e28-4336-9611-0ed53748f9ad.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5559aba3-065a-45bb-9c3c-6fcf6c730f04.
# > Parent node text: PAGE 31Finding the Right
# AI Job for YouCHAPTER 9
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 50937058-d173-41ce-8c2f-5b0c8439ce05.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 679cdb6b-d62c-4190-aad6-7832a4f4d2c9.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: c5902773-1131-4ab6-b0fc-e36f9bab1634.
# > Parent node text: PAGE 31Finding the Right
# AI Job for YouCHAPTER 9
# JOBS
#
# > Merging 4 nodes into parent node.
# > Parent node id: 157486a5-665b-479e-92e7-a3755a8d65bc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a48cf4d4-1209-47af-bcc2-bde9d021b9df.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 2f75b3e6-5317-4156-b4ff-ff7b1582586a.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9f3c22f7-1f6d-4b86-b120-568f19bf0dec.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 7db48f01-933e-4637-963a-f29452bed96c.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 4 nodes into parent node.
# > Parent node id: c71d347e-39ac-4a71-ab6c-183cc55baa0d.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: e5b01757-2eb1-4c9d-bfc4-4e7520971e58.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 45efbeb9-47df-4f51-980c-85098f2bc5b2.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ccb3138c-6c4f-438e-b71c-5ad70c2ddc7e.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ddbf6e5f-3bbb-4503-949c-170eab1cf4e3.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: b39a730f-a374-4718-a780-7d36f4f72b7c.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 9164a307-63d6-4c11-b4f6-4c64a32d7cf0.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 22b11911-4ac3-415e-bee2-b5f58fb4f3b9.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8c22463e-d3f9-46c5-8cf9-7b7f8c2f4142.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 82336ad7-ad0a-4f6f-8558-791e13f5ee59.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 333da981-0ec4-45c9-958b-06a05ef5129b.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 3 nodes into parent node.
# > Parent node id: 73a147b2-f15b-4aad-8901-1e21574d1be2.
# > Parent node text: PAGE 40Make Every Day CountFinal Thoughts
# Every year on my birthday, I get to thinking about the ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: b74d5cea-897d-430c-92ba-748dcba3e699.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 47904e42-7c52-41e0-a08c-54e01011a0ef.
# > Parent node text: PAGE 40Make Every Day CountFinal Thoughts
# Every year on my birthday, I get to thinking about the ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3d4356f9-6ee3-4155-8fc0-a14817cd0191.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 4 nodes into parent node.
# > Parent node id: ff9a8693-d146-414e-bdc3-b34dc1e739e5.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c19781c6-5179-466b-b858-85a4e6c25274.
# > Parent node text: I’ve found EDA particularly
# useful in data-centric AI development, where analyzing errors and ga...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 97c7749c-59c7-47c0-a2c7-ac7ec8943317.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0b9dee3c-277f-4465-8c07-64936f259673.
# > Parent node text: PAGE 14Scoping Successful
# AI ProjectsCHAPTER 4
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9801bec4-fc2e-4dc5-8e2e-0b0850a95db7.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: d400223f-015f-4e54-9c86-9de8c4bcacdd.
# > Parent node text: PAGE 14Scoping Successful
# AI ProjectsCHAPTER 4
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: f6433f00-dac6-40f3-9cbf-001c4c159d4f.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 2 nodes into parent node.
# > Parent node id: a48cf4d4-1209-47af-bcc2-bde9d021b9df.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9f3c22f7-1f6d-4b86-b120-568f19bf0dec.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 6 nodes into parent node.
# > Parent node id: 6bfd102b-ced2-4287-b4b0-9ebe9d9167b9.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0a5d6629-ed56-44c5-b3dc-8788e71d83d3.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 13ecd5a4-c19d-49e8-bdf3-739711fcd910.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a48cf4d4-1209-47af-bcc2-bde9d021b9df.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 58a4ea0c-6c14-46bf-9eea-1f99eda168fa.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7fe4e2ca-a36c-411e-9177-cdb17f069893.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9f3c22f7-1f6d-4b86-b120-568f19bf0dec.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1d39594d-09f2-46ef-8b23-12fc25b0b765.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 2 nodes into parent node.
# > Parent node id: a48cf4d4-1209-47af-bcc2-bde9d021b9df.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9f3c22f7-1f6d-4b86-b120-568f19bf0dec.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 37cb673a-fedc-4d2d-9378-b0d412beca35.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 0a0c12c5-b2e0-4399-a3f2-a3c04f9f1e5a.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e0e410fb-b57e-45e9-9488-8b62b665677b.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: a48cf4d4-1209-47af-bcc2-bde9d021b9df.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9f3c22f7-1f6d-4b86-b120-568f19bf0dec.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 9164a307-63d6-4c11-b4f6-4c64a32d7cf0.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 3 nodes into parent node.
# > Parent node id: b39a730f-a374-4718-a780-7d36f4f72b7c.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 22b11911-4ac3-415e-bee2-b5f58fb4f3b9.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 82336ad7-ad0a-4f6f-8558-791e13f5ee59.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8c22463e-d3f9-46c5-8cf9-7b7f8c2f4142.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 333da981-0ec4-45c9-958b-06a05ef5129b.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11

# %%
from trulens_eval import Tru
Tru().get_leaderboard(app_ids=[])
# Out:
#         Groundedness  Context Relevance  Answer Relevance    latency  \
# app_id
# app_1       0.873313           0.260985          0.965217  47.291667
# app_0       0.825678           0.271528          0.991667  47.291667
#
#         total_cost
# app_id
# app_1     0.001964
# app_0     0.003781

# %%
Tru().run_dashboard()
# Out:
# Starting dashboard ...
# Config file already exists. Skipping writing process.
# Credentials file already exists. Skipping writing process.
# Dashboard already running at path:   Submit this IP Address: 35.231.56.55
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %%
## display output texts
import textwrap
records, feedback = Tru().get_records_and_feedback(app_ids=[]) ## records is a pandas dataframe
n_rows = 10
for i in range(n_rows):
    input, output = records.loc[i, ['input', 'output']]
    print('👉', textwrap.fill(input, 100))
    print('▪️', textwrap.fill(output, 100), '\n')
# Out:
# 👉 "In the context of job switching, what advantages does working in a startup offer over a big
# company, particularly for someone looking to transition into an AI role?"
# ▪️ "Working in a startup can offer advantages over a big company for someone looking to transition into
# an AI role. Startups usually have a smaller team and may not have enough people to handle all the AI
# tasks they need. This means that even if it's not your official job, if you're able to help with AI
# tasks, your work is likely to be appreciated. This can lay the groundwork for a possible role switch
# without needing to leave the company. In contrast, big companies often have a more rigid reward
# system that focuses on rewarding employees for doing their job well within their designated scope,
# rather than rewarding contributions outside of their job's scope."
#
# 👉 "Explain the scenario planning exercise mentioned in the context of the Covid-19 pandemic. How can
# this method be applied to personal life situations such as job hunting or exam preparation?"
# ▪️ "The scenario planning exercise mentioned in the context of the Covid-19 pandemic involved imagining
# different recovery scenarios (quick, medium, and slow) and making plans for managing each case. This
# exercise helped the person prioritize their actions and regain a sense of control in the face of
# uncertainty.\n\nThis method can be applied to personal life situations such as job hunting or exam
# preparation by considering different possible scenarios and creating plans of action for each
# scenario. For example, if you're unsure about passing an exam, getting a job offer, or being granted
# a visa, you can write out what you would do in each of the likely scenarios. By thinking through the
# possibilities and following through on plans, you can navigate the future effectively and be
# prepared for whatever it brings. Additionally, having training in AI and statistics can help
# calculate probabilities for each scenario, providing a more informed approach to decision-making."
#
# 👉 "In the context of project selection and execution, explain the difference between the \"Ready, Aim,
# Fire\" and \"Ready, Fire, Aim\" approaches. Provide examples where each approach might be more
# beneficial."
# ▪️ "The \"Ready, Aim, Fire\" approach refers to carefully planning and validating a project before
# executing it. This approach is beneficial when the cost of execution is high and when studying the
# market or conducting research can provide valuable insights. For example, if you have built a
# customer-service chatbot for retailers and are considering expanding it to restaurants, taking the
# time to study the restaurant market before starting development can help reduce the risk of wasting
# time and resources.\n\nOn the other hand, the \"Ready, Fire, Aim\" approach involves jumping into
# development and starting execution quickly. This approach is more suitable when the cost of
# execution is low and when it is feasible to determine the direction and make necessary tweaks along
# the way. For instance, if you can build a prototype quickly to test if users want the product and if
# pivoting or canceling after a small amount of work is acceptable, then it makes sense to consider
# the \"Ready, Fire, Aim\" approach.\n\nBoth approaches have their advantages and the best choice
# depends on the specific situation, the cost of execution, and the level of certainty or risk
# involved."
#
# 👉 "Discuss the importance of working on projects that complement your career goals. How can these
# projects serve as stepping stones to larger projects and contribute to technical growth and skill
# progression?"
# ▪️ "Working on projects that complement your career goals is important because they can serve as
# stepping stones to larger projects and contribute to technical growth and skill progression. These
# projects allow you to develop and strengthen your skills in a practical and hands-on manner. By
# working on projects that align with your career goals, you can gain valuable experience and
# expertise in your desired field.\n\nThese projects can also help you expand your technical knowledge
# and capabilities. They provide opportunities to challenge yourself and learn new skills, while also
# allowing you to apply and refine your existing skills. As you successfully complete these projects,
# you will gain confidence and competence in handling more complex and demanding
# tasks.\n\nFurthermore, working on projects that align with your career goals can open doors to
# larger projects in the future. When you demonstrate your ability to deliver results and make a
# meaningful impact through your projects, you increase your chances of being entrusted with more
# significant and impactful projects. These larger projects can further enhance your technical growth
# and skill progression, as they often involve greater complexity and require advanced problem-solving
# abilities.\n\nIn summary, working on projects that complement your career goals is crucial for your
# professional development. These projects not only serve as stepping stones to larger projects but
# also contribute to your technical growth and skill progression. They provide opportunities to learn,
# apply, and refine your skills, ultimately helping you achieve your career aspirations."
#
# 👉 "According to the text, what are some of the key areas of mathematics that are relevant to machine
# learning and why are they important in the field of AI?"
# ▪️ "Key areas of mathematics that are relevant to machine learning include linear algebra, probability
# and statistics, and calculus. These areas are important in the field of AI because they provide the
# foundational knowledge and tools necessary to understand and develop machine learning algorithms.
# Linear algebra is essential for understanding vectors, matrices, and their manipulations, which are
# fundamental to many machine learning techniques. Probability and statistics are crucial for modeling
# uncertainty and making predictions based on data. Calculus is useful for optimization algorithms and
# understanding the behavior of complex mathematical functions. Overall, a solid understanding of
# these mathematical concepts is essential for building and applying machine learning models
# effectively in AI."
#
# 👉 "The text mentions BJ Fogg's approach to building new habits. How can this approach be applied to
# the process of learning technical skills for a promising AI career?"
# ▪️ "Starting small and succeeding is the key to building new habits, according to BJ Fogg's approach.
# This approach can be applied to the process of learning technical skills for a promising AI career
# by starting with small and achievable goals. Instead of overwhelming oneself with trying to learn
# everything at once, aspiring AI professionals can begin by focusing on learning foundational skills.
# By consistently dedicating a little bit of time each week to learning and gradually increasing the
# complexity of the skills being acquired, individuals can build a habit of continuous learning and
# make significant progress over time. This approach allows for a steady pace of learning and ensures
# that the knowledge gained is absorbed effectively."
#
# 👉 "What is an informational interview and how can it be beneficial for someone looking to switch roles
# or industries, particularly in the field of AI?"
# ▪️ "An informational interview is a technique where someone interviews a person in a company or role
# they are interested in to learn more about their work. It is separate from searching for a job and
# can be beneficial for someone looking to switch roles or industries, especially in the field of AI.
# By conducting informational interviews, individuals can gain insights into the specific tasks,
# skills, and requirements of different AI roles in various companies. This helps them understand what
# the job entails and what skills are needed to be successful. Additionally, informational interviews
# can provide information about the algorithms, deployment processes, and software stacks used in a
# particular company. This knowledge can be invaluable for someone transitioning into an AI job for
# the first time."
#
# 👉 "What are some of the steps involved in a typical job search process and how can one increase their
# odds of finding a position that supports their career growth?"
# ▪️ "To increase the odds of finding a position that supports career growth, there are several steps
# involved in a typical job search process. First, it is important to research roles and companies
# online or by talking to friends. This will help in identifying potential opportunities that align
# with career goals. Additionally, arranging informal informational interviews with people in
# companies of interest can provide valuable insights.\n\nOnce potential opportunities have been
# identified, one can either apply directly or try to get a referral from someone on the inside.
# Referrals can often increase the chances of getting noticed by the hiring team. \n\nWhen it comes to
# the application process, it is crucial to pay attention to the fundamentals. This includes having a
# compelling resume and portfolio of technical projects that showcase relevant skills and experience.
# Customizing communications with each company to explain why you are a good fit is also
# important.\n\nPreparing for interviews is another key step. It is recommended to ask the recruiter
# what to expect and take the time to review and practice answers to common interview questions.
# Brushing up on key skills and studying technical materials to ensure they are fresh in mind is also
# beneficial. Taking notes during interviews can help in remembering important details.\n\nLastly, it
# is important to approach interviews and offer negotiations with a win-win mindset. It is essential
# to proceed respectfully and responsibly throughout the process."
#
# 👉 "According to the text, what are some key elements to consider when preparing for a job interview in
# the AI field?"
# ▪️ "When preparing for a job interview in the AI field, it is important to consider several key
# elements. First, it is recommended to conduct informational interviews with individuals who are
# already working in the AI field to gain insights into the specific job and company. Researching the
# interviewee and the company in advance is also crucial to arrive with thoughtful questions.
# Additionally, it is important to understand the evolving nature of the AI field and the different
# ways job titles and responsibilities can vary across companies. Finally, it is beneficial to learn
# about the algorithms, deployment processes, and software stacks used by a particular company in
# order to be well-prepared for the interview."
#
# 👉 "How does the document suggest you approach the job-search process and what role does your community
# play in this process?"
# ▪️ "The document suggests approaching the job-search process in an incremental manner. It advises
# starting by identifying possible roles and conducting informational interviews to gather more
# information. If these conversations reveal that more learning is needed, it is recommended to take
# that as a positive and have a clear path forward. The document also emphasizes the importance of
# networking and seeking help from the community. It suggests reaching out to friends, associates, and
# people in your immediate community who may have experience and can provide advice, inside knowledge,
# and referrals to potential employers. Additionally, it encourages paying it forward by helping
# others in the community who may be seeking informational interviews or guidance in their job
# search."
