# %% [markdown]
# <a href="https://colab.research.google.com/github/Nov05/Google-Colaboratory/blob/master/2019_06_29_plotly_express_and_dash_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create by Wenjing Liu on 2019-06-29
# Google-Colaboratory

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Install Plotly Express

# %%
# !pip install plotly_express

# %%
import numpy as np
import pandas as pd

import plotly_express as px
from plotly.offline import init_notebook_mode

import warnings
warnings.filterwarnings('ignore')
# warnings.filterwarnings(action='once')

# %%
# you can ignore this code block
# check matplotlib backends
# %matplotlib --list
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'inline', 'ipympl', 'widget']

# %% [markdown]
# # Display Plotly Express in Colab
# https://medium.com/@jmancuso82/gapminder-animated-visualization-w-plotly-express-37aa594683c6

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %% [markdown]
# # Experiment Plotly Express

# %% [markdown]
# **YouTube: Explore Your Data and Then Let Others Do It Too: Plotly Express and Dash - Nicolas Kruchten**
# https://www.youtube.com/watch?time_continue=109&v=5Cw4JumJTwo

# %%
tips = px.data.tips()
print(tips.shape)
tips.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
configure_plotly_browser_state()
px.scatter(tips, x="total_bill", y="tip",
           marginal_x="box", marginal_y="violin",
           color="sex",
           trendline="ols",
          )
# tip: double click the plot to unzoom
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="9d547810-9417-41d4-bd9f-c3961d919435" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9d547810-9417-41d4-bd9f-c3961d919435")) {
#                     Plotly.newPlot(
#                         '9d547810-9417-41d4-bd9f-c3961d919435',
# ...

# %%
configure_plotly_browser_state()
px.scatter(tips, x="total_bill", y="tip",
           color="sex",
           trendline="ols",
           facet_col="smoker"
          )
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="62954fc5-d6bc-4b8a-ae66-5fd2656ecd54" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("62954fc5-d6bc-4b8a-ae66-5fd2656ecd54")) {
#                     Plotly.newPlot(
#                         '62954fc5-d6bc-4b8a-ae66-5fd2656ecd54',
# ...

# %%
configure_plotly_browser_state()
px.scatter(tips, x="total_bill", y="tip",
           color="sex",
           trendline="ols",
           facet_row="day",
           facet_col="smoker"
          )
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="469048c0-d837-4c61-96c8-cebfd424a361" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("469048c0-d837-4c61-96c8-cebfd424a361")) {
#                     Plotly.newPlot(
#                         '469048c0-d837-4c61-96c8-cebfd424a361',
# ...

# %%
configure_plotly_browser_state()
px.scatter(tips, x="total_bill", y="tip",
           facet_row="time",
           facet_col="day",
           category_orders={"day":["Thur","Fri","Sat","Sun"]}
          )
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="71c54968-bf41-47bc-8154-6618084e4596" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("71c54968-bf41-47bc-8154-6618084e4596")) {
#                     Plotly.newPlot(
#                         '71c54968-bf41-47bc-8154-6618084e4596',
# ...

# %%
configure_plotly_browser_state()
px.bar(tips, x="day", y="total_bill",
       category_orders={"day":["Thur","Fri","Sat","Sun"]}
      )
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="fe52061a-1332-4dfb-b392-d5b3599c98d9" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fe52061a-1332-4dfb-b392-d5b3599c98d9")) {
#                     Plotly.newPlot(
#                         'fe52061a-1332-4dfb-b392-d5b3599c98d9',
# ...

# %%
configure_plotly_browser_state()
px.scatter_matrix(tips)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="434444bc-3f74-462e-b108-a0f287f032ad" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("434444bc-3f74-462e-b108-a0f287f032ad")) {
#                     Plotly.newPlot(
#                         '434444bc-3f74-462e-b108-a0f287f032ad',
# ...

# %% [markdown]
# # Install Plotly Dash
# https://dash.plot.ly/installation

# %%
# !pip install dash==1.0.0  # The core dash backend
# !pip install dash-daq==0.1.0  # DAQ components (newly open-sourced!)

# %% [markdown]
# # Tunnel Dash app port 8050 to outside

# %%
# How to run a Dash app in Google Colab

### Install ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

#############################################################
### Requirements
#############################################################
### Run ngrok to tunnel Dash app port 8050 to the outside world. 
### This command runs in the background.
### e.g. https://d47aa609.ngrok.io (it would change every time you run this code block)
# get_ipython().system_raw('./ngrok http 8050 &')
#############################################################
### Get the public URL where you can access the Dash app. Copy this URL.
# ! curl -s http://localhost:4040/api/tunnels | python3 -c \
#     "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
#############################################################    
### Install Dash
# !pip install dash==0.31.1  # The core dash backend
# !pip install dash-html-components==0.13.2  # HTML components
# !pip install dash-core-components==0.39.0  # Supercharged components
# !pip install dash-table==3.1.7  # Interactive DataTable component (new!)
#############################################################

# %%
### Run ngrok to tunnel Dash app port 8050 to the outside world. 
### This command runs in the background.
### e.g. https://d47aa609.ngrok.io (it would change every time you run this code block)
get_ipython().system_raw('./ngrok http 8050 &')

### Get the public URL where you can access the Dash app. Copy this URL.
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
    
# Click on the link displayed below after you start your app.
# Out:
# https://0083b687.ngrok.io

# %% [markdown]
# # Run Dash in Colab
# https://community.plot.ly/t/problem-running-dash-in-google-colab-notebook/11583/4

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div(children=[
html.H1(children="Hello Dash"),
html.Div(children='''
    Dash: A web application framework for Python.
'''),

dcc.Graph(
    id='example-graph',
    figure={
        'data':[
            {'x':[1, 2, 3], 'y':[4, 1, 2], 'type':'bar', 'name':'SF'},
            {'x':[1, 2, 3], 'y':[2, 4, 5], 'type':'bar', 'name':u'Montréal'},
        ],
        'layout':{
            'title':'Dash Data Visualization'
        }
    }
)
])

#############################################################
## This might have to do with the new version of flask (1.0+). 
## It started coming up when I upgraded. If you use flask 0.12 
## for example it should be fine.
## NameError: name 'name' is not defined
#############################################################
# if name == "main":
#   app.run_server(debug=True)
#############################################################

if __name__ == '__main__':
    app.run_server()

# %% [markdown]
# ### Or you could export the code block to .py file, then run the file

# %%
# %%writefile my_app.py

import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()

app.layout = html.Div(children=[
html.H1(children="Hello Dash"),
html.Div(children='''
    Dash: A web application framework for Python.
'''),

dcc.Graph(
    id='example-graph',
    figure={
        'data':[
            {'x':[1, 2, 3], 'y':[4, 1, 2], 'type':'bar', 'name':'SF'},
            {'x':[1, 2, 3], 'y':[2, 4, 5], 'type':'bar', 'name':u'Montréal'},
        ],
        'layout':{
            'title':'Dash Data Visualization'
        }
    }
)
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Overwriting my_app.py

# %%
# !python my_app.py
# Out:
#  * Serving Flask app "my_app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # Access Dash app in Colab

# %% [markdown]
# https://stackoverflow.com/questions/53622518/launch-a-dash-app-in-a-google-colab-notebook
# Dec 4 '18 at 22:56
# To access the Dash app, copy & paste the **ngrok.io-URL** (e.g. https://7bf800a2.ngrok.io) above to a new brower tab (**NOT** 127.0.0.1:8050) and wait a few seconds.
#
# **The result should look like this.**
#
# <img src="https://drive.google.com/uc?id=1TtGnr8_K846UHNQbwNQDBQus4ff1G0HV">

# %% [markdown]
# # Experiment Plotly Dash

# %% [markdown]
# **YouTube: Explore Your Data and Then Let Others Do It Too: Plotly Express and Dash - Nicolas Kruchten**
# https://youtu.be/5Cw4JumJTwo?t=597

# %%
# You can ignore this code block
# !lsof -i :8050
# Out:
# COMMAND PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# python3 215 root   76u  IPv4  62305      0t0  TCP localhost:8050 (LISTEN)
# ngrok   326 root    3u  IPv4  62402      0t0  TCP localhost:39382->localhost:8050 (ESTABLISHED)
# ngrok   326 root    6u  IPv4  64529      0t0  TCP localhost:39428->localhost:8050 (ESTABLISHED)
# ngrok   326 root    8u  IPv4  64852      0t0  TCP localhost:39552->localhost:8050 (ESTABLISHED)

# %% [markdown]
# ### Example 1

# %%
# run this code black to get a link, then run your Dash app
get_ipython().system_raw('./ngrok http 8050 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# click on the link below after you start your Dash app
# Out:
# http://088b7c31.ngrok.io

# %%
# here is a simple Dash app. run it!

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1("Demo: Plotly Express in Dash with Tips Dataset"),
    dcc.Input(id="x"),
    html.H2(id="x_out")
])

@app.callback(Output("x_out", "children"), [Input("x", "value")])
def cb(x):
  return x

app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Example 2

# %%
# run this code black to get a link, then run your Dash app
get_ipython().system_raw('./ngrok http 8050 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# click on the link below after you start your Dash app
# Out:
# https://ce239b77.ngrok.io

# %%
# here is another simple Dash app
# a scatter plot

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly_express as px

tips = px.data.tips()
col_options = [dict(label=x, value=x) for x in tips.columns]

app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1("Demo: Plotly Express in Dash with Tips Dataset"),
    dcc.Dropdown(id="x", options=col_options),
    dcc.Graph(id="graph", figure=px.scatter(tips))
])

@app.callback(Output("graph", "figure"), [Input("x", "value")])
def cb(x):
  return px.scatter(tips, x=x)

app.run_server()

# %% [markdown]
# ### Example 3

# %%
# run this code black to get a link, then run your Dash app
get_ipython().system_raw('./ngrok http 8050 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# click on the link below after you start your Dash app

# %%
# here is new simple Dash app

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly_express as px

tips = px.data.tips()
col_options = [dict(label=x, value=x) for x in tips.columns]

app = dash.Dash(__name__)

app.layout = html.Div(children=[
    html.H1("Demo: Plotly Express in Dash with Tips Dataset"),
    dcc.Dropdown(id="x", options=col_options),
    dcc.Graph(id="graph", figure=px.scatter(tips))
])

@app.callback(Output("graph", "figure"), [Input("x", "value")])
def cb(x):
  return px.scatter(tips, x=x)

app.run_server()
